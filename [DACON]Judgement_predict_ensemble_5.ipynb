# %%
import pandas as pd
import numpy as np
import random
import os
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import RidgeClassifier, PassiveAggressiveClassifier, Perceptron, LogisticRegression, SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import VotingClassifier, AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier
from sklearn.utils import check_random_state
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

from nltk.tokenize import word_tokenize, sent_tokenize
import text_hammer as th

from scipy import sparse

from tqdm import tqdm

# %%
train = pd.read_csv('Data/train.csv')
test = pd.read_csv('Data/test.csv')
print("Number of rows in train dataset : ", train.shape[0])
# Out:
# Number of rows in train dataset :  2478

# %%
CFG = {
    # 'EPOCHS': 20,
    # 'LEARNING_RATE': 2e-5,
    # 'BATCH_SIZE': 8,
    'SEED': 42,
    # 'MAX_LEN': 384,
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    check_random_state(seed)

seed_everything(CFG['SEED']) # Seed 고정

# %%
# train 데이터프레임에서 facts 열의 각 행(row)에 대해 문장 수를 세는 함수를 정의합니다.
def count_sentences(row):
    sentences = sent_tokenize(row)
    return len(sentences)

# facts 열의 문장 수를 세어서 새로운 'num_sentences' 열을 추가합니다.
train['num_sentences'] = train['facts'].apply(lambda x: count_sentences(x))

# 문장 수가 1개인 행(row)들만 선택합니다.
rows_with_single_sentence = train[train['num_sentences'] == 1]

# 결과를 DataFrame으로 출력합니다.
rows_with_single_sentence
# Out:
#               ID                                        first_party  \
# 248   TRAIN_0248                                           New York
# 554   TRAIN_0554                                   Riverside County
# 630   TRAIN_0630                                       Earl R. Deen
# 764   TRAIN_0764                                             Nollan
# 858   TRAIN_0858                                           Morrison
# 1104  TRAIN_1104                                Eastern Enterprises
# 1285  TRAIN_1285                                              Smith
# 1319  TRAIN_1319  National Association for the Advancement of Co...
# 1329  TRAIN_1329                                      United States
# 1461  TRAIN_1461                                              Jones
# 1595  TRAIN_1595               San Francisco Arts & Athletics, Inc.
# 1741  TRAIN_1741                                            Poelker
# 2028  TRAIN_2028                  National Treasury Employees Union
# 2113  TRAIN_2113                                           Illinois
# 2154  TRAIN_2154                               City of Philadelphia
# 2309  TRAIN_2309                      New Energy Company of Indiana
#
#                                    second_party  \
# 248                                      Ferber
# 554                                  McLaughlin
# 630   Gulf, Colorado & Santa Fe Railway Company
# 764               California Coastal Commission
# 858                                       Olson
# 1104                                      Apfel
# 1285              Daily Mail Publishing Company
# 1319                                     Button
# 1329                                   Paradise
# 1461                    Alfred H. Mayer Company
# 1595            United States Olympic Committee
# 1741                                        Doe
# 2028                                   Von Raab
# 2113                                    Perkins
# 2154                                 New Jersey
# 2309                                    Limbach
#
#                                                   facts  first_party_winner  \
# 248   A New York child pornography law prohibited pe...                   1
# 554   McLaughlin was arrested without a warrant and ...                   1
# 630                                    Not Available.\n                   1
# 764   The California Coastal Commission required own...                   1
# 858   The Ethics in Government Act of 1978 created a...                   1
# 1104                               Currently unknown.\n                   1
# 1285  A West Virginia statute made it a crime for a ...                   0
# 1319  The NAACP was prosecuted for violating a Virgi...                   1
# 1329  In response to a series of NAACP-initiated law...                   0
# 1461  Jones, a black man, charged that a real estate...                   1
# 1595                           Currently unavailable.\n                   0
# 1741  A St. Louis policy prohibited non-therapeutic ...                   1
# 2028  In 1986, the United States Customs Service imp...                   0
# 2113  While being held in jail, Perkins freely confe...                   1
# 2154  A New Jersey law prohibited the importation of...                   1
# 2309  An Indiana law gave a tax credit against the O...                   1
#
#       num_sentences
# 248               1
# 554               1
# 630               1
# 764               1
# 858               1
# 1104              1
# 1285              1
# 1319              1
# 1329              1
# 1461              1
# 1595              1
# 1741              1
# 2028              1
# 2113              1
# 2154              1
# 2309              1

# %%
# 특정 인덱스 삭제 - Not available, Currently available, Currently unknown
indexes_to_remove = [630, 1104, 1595]
train = train.drop(indexes_to_remove)
train = train.reset_index(drop=True)

# %%
# 'facts' 열에서 'Not available'이나 'Currently available', 'Currently unknown' 문구가 있는지 확인
is_not_available = train['facts'].str.contains('Not available', case=False)
is_currently_available = train['facts'].str.contains('Currently available', case=False)
is_currently_unknown = train['facts'].str.contains('Currently unknown', case=False)

# 결과 출력 -> 위 문구 외에 다른 문장 있으므로 패스
train[is_not_available | is_currently_available | is_currently_unknown]
# Out:
#               ID                                       first_party  \
# 86    TRAIN_0086                                             Brown
# 574   TRAIN_0574                               Gil Garcetti et al.
# 648   TRAIN_0649                        Friends of the Earth, Inc.
# 1061  TRAIN_1062  Kenneth F. Fare, Acting Chief Probation Officer
# 1610  TRAIN_1613               Atlantic Sounding Co., Inc., et al.
# 2230  TRAIN_2233                      Verizon Communications, Inc.
#
#                                     second_party  \
# 86                                     Louisiana
# 574                             Richard Ceballos
# 648   Laidlaw Environmental Services (TOC), Inc.
# 1061                                  Michael C.
# 1610                           Edgar L. Townsend
# 2230           Federal Communications Commission
#
#                                                   facts  first_party_winner  \
# 86    The Audubon Regional library operated three br...                   1
# 574   Richard Ceballos, an employee of the Los Angel...                   1
# 648   After Laidlaw Environmental Services, Inc. bou...                   1
# 1061  Police arrested Michael C., a 16 year old, on ...                   1
# 1610  In July 2005, Edgar Townsend was allegedly inj...                   0
# 2230  The Telecommunications Act of 1996 entitles ne...                   0
#
#       num_sentences
# 86                7
# 574               6
# 648              13
# 1061              9
# 1610             13
# 2230              5

# %%
def get_clean(x):
    x = str(x).lower().replace('\\', '').replace('_', ' ')
    x = th.cont_exp(x)
    x = th.remove_emails(x)
    x = th.remove_urls(x)
    x = th.remove_html_tags(x)
    x = th.remove_rt(x)
    x = th.remove_accented_chars(x)
    x = th.remove_special_chars(x)
    x = re.sub("(.)\\1{2,}", "\\1", x)
    return x

# %%
# 라벨 위치를 바꾸는 함수
def swap_labels(row):
    if row['first_party_winner'] == 1:
        row['first_party_winner'] = 0
    else:
        row['first_party_winner'] = 1
    return row

# %%
train = train[train['num_sentences'] >= 3]

# %%
# first_party와 second_party 열의 라벨 위치를 바꾸고 first_party_winner 열의 값을 반전시킨 데이터프레임 생성
train_swapped = train.copy()
train_swapped[['first_party', 'second_party']] = train_swapped[['second_party', 'first_party']]
train_swapped = train_swapped.apply(swap_labels, axis=1)
train_extended = pd.concat([train, train_swapped])
train_extended['facts'] = train_extended['facts'].apply(lambda x : get_clean(x))
train_extended['first_party'] = train_extended['first_party'].apply(lambda x : get_clean(x))
train_extended['second_party'] = train_extended['second_party'].apply(lambda x : get_clean(x))
train_extended.reset_index(drop=True, inplace=True)

test['facts'] = test['facts'].apply(lambda x: get_clean(x))
test['first_party'] = test['first_party'].apply(lambda x : get_clean(x))
test['second_party'] = test['second_party'].apply(lambda x : get_clean(x))

# %%
train_extended
# Out:
#               ID                        first_party  \
# 0     TRAIN_0000                    phil a st amant
# 1     TRAIN_0001                     stephen duncan
# 2     TRAIN_0002                  billy joe magwood
# 3     TRAIN_0003                         linkletter
# 4     TRAIN_0004                 william earl fikes
# ...          ...                                ...
# 4777  TRAIN_2473  renewable fuels association et al
# 4778  TRAIN_2474             alliance bond fund inc
# 4779  TRAIN_2475                      united states
# 4780  TRAIN_2476                             st cyr
# 4781  TRAIN_2477           westview instruments inc
#
#                                    second_party  \
# 0                             herman a thompson
# 1                                lawrence owens
# 2                   tony patterson warden et al
# 3                                        walker
# 4                                       alabama
# ...                                         ...
# 4777  hollyfrontier cheyenne refining llc et al
# 4778           grupo mexicano de desarrollo s a
# 4779                                    peguero
# 4780     immigration and naturalization service
# 4781                                    markman
#
#                                                   facts  first_party_winner  \
# 0     on june 27 1962 phil st amant a candidate for ...                   1
# 1     ramon nelson was riding his bike when he suffe...                   0
# 2     an alabama state court convicted billy joe mag...                   1
# 3     victor linkletter was convicted in state court...                   0
# 4     on april 24 1953 in selma alabama an intruder ...                   1
# ...                                                 ...                 ...
# 4777  congress amended the clean air act through the...                   0
# 4778  alliance bond fund inc an investment fund purc...                   0
# 4779  in 1992 the district court sentenced manuel d ...                   1
# 4780  on march 8 1996 enrico st cyr a lawful permane...                   1
# 4781  herbert markman owns the patent to a system th...                   1
#
#       num_sentences
# 0                 7
# 1                 7
# 2                 8
# 3                 3
# 4                 9
# ...             ...
# 4777              5
# 4778              7
# 4779              6
# 4780              8
# 4781              6
#
# [4782 rows x 6 columns]

# %%
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 3), min_df=3)
def get_vector(vectorizer, df, train_mode):
    if train_mode:
        X_facts = vectorizer.fit_transform(df['facts'])
    else:
        X_facts = vectorizer.transform(df['facts'])
    X_party1 = vectorizer.transform(df['first_party'])
    X_party2 = vectorizer.transform(df['second_party'])
    
    X = sparse.hstack([X_party1, X_party2, X_facts])
    return X

# %%
X_train = get_vector(vectorizer, train_extended, True)
Y_train = train_extended["first_party_winner"]
X_test = get_vector(vectorizer, test, False)

# %%
X_train = X_train.toarray()
X_test = X_test.toarray()

# %%
ridge_model = RidgeClassifier()
ETC_model = ExtraTreesClassifier()
logistic_model = LogisticRegression()
RFC_model = RandomForestClassifier()
ABS_model = AdaBoostClassifier()
SGD_model = SGDClassifier()
xgb_model = XGBClassifier()
lgbm_model = LGBMClassifier()
cat_model = CatBoostClassifier()

ridge_model.fit(X_train, Y_train)
ETC_model.fit(X_train, Y_train)
logistic_model.fit(X_train, Y_train)
RFC_model.fit(X_train, Y_train)
ABS_model.fit(X_train, Y_train)
SGD_model.fit(X_train, Y_train)
xgb_model.fit(X_train, Y_train)
lgbm_model.fit(X_train, Y_train)
cat_model.fit(X_train, Y_train)

# VotingClassifier 생성
voting_model = VotingClassifier(
    estimators=[('ridge', ridge_model), ('ETC', ETC_model), ('logistic', logistic_model), ('RFC', RFC_model), ('ABS', ABS_model), ('SGD', SGD_model), ('xgb', xgb_model), ('lgbm', lgbm_model), ('cat', cat_model)], 
    voting='hard'
)

voting_model.fit(X_train, Y_train)

# %%
submit = pd.read_csv('Data/sample_submission.csv')

# %%
pred = voting_model.predict(X_test)

# %%
submit['first_party_winner'] = pred
submit.to_csv('./submit_voting_ensemble_5.csv', index=False)
print('Done')
# Out:
# Done
